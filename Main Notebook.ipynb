# %%
import pandas as pd 

#make bar graph for worldwide profit vs studio -easy
#make new df for directors vs popularity, directors vs worldwide profit, and directors vs domestic profit, and make
#those charts too -3 hours

# %% [markdown]
# # Data Wrangling:

# %% [markdown]
# # Box Office Mojo DB

# %%
#chart 1

BOM = pd.read_csv("zippedData/bom.movie_gross.csv") 

BOM 

#drop unnecessary columns and concat columns that are relevant
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 0        652000000  2010
# 1        691300000  2010
# 2        664300000  2010
# 3        535700000  2010
# 4        513900000  2010
# ...            ...   ...
# 3382           NaN  2018
# 3383           NaN  2018
# 3384           NaN  2018
# 3385           NaN  2018
# 3386           NaN  2018
#
# [3387 rows x 5 columns]

# %%
BOM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
BOM.shape
# Out:
# (3387, 5)

# %%
BOM.describe()

#50% of them are made from 2014 and before that year
# Out:
#        domestic_gross         year
# count    3.359000e+03  3387.000000
# mean     2.874585e+07  2013.958075
# std      6.698250e+07     2.478141
# min      1.000000e+02  2010.000000
# 25%      1.200000e+05  2012.000000
# 50%      1.400000e+06  2014.000000
# 75%      2.790000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %% [markdown]
# # TMDB DB

# %%
#chart 2

t = pd.read_csv("zippedData/tmdb.movies.csv")

t

#SQLite analysis 

    `im.db.zip`
  * Zipped SQLite database (you will need to unzip then query using SQLite)
  * `movie_basics` and `movie_ratings` tables are most relevant
* `bom.movie_gross.csv.gz`
  * Compressed CSV file (you can open without expanding the file using `pd.read_csv`)
# Out:
#   File "<tokenize>", line 10
#     * Zipped SQLite database (you will need to unzip then query using SQLite)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# # Movie Info TSV

# %%
#chart 3

m = pd.read_csv('zippedData/rt.movie_info.tsv',delimiter='\t',encoding='windows-1252') 
m
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
m.isna().sum()
# Out:
# id                 0
# synopsis          62
# rating             3
# genre              8
# director         199
# writer           449
# theater_date     359
# dvd_date         359
# currency        1220
# box_office      1220
# runtime           30
# studio          1066
# dtype: int64

# %%
m.info()

# %%
m.describe()

# %% [markdown]
# # Movie Reviews

# %%
#chart 4

mr = pd.read_csv('zippedData/rt.reviews.tsv',delimiter='\t',encoding='windows-1252')
mr

 #ratings determine which types of movies they should make 

# do the reviews correlate with the domestic and worldwide profit? Maybe not, because people 
#first see the movie, then they rate and review the movie. So the profit may just be based
#on the popularity of the movies...friends tell friends and they all see the movie again and 
#again.
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic         publisher                date
# 0             PJ Nabarro           0   Patrick Nabarro   November 10, 2018
# 1         Annalee Newitz           0           io9.com        May 23, 2018
# 2           Sean Axmaker           0  Stream on Demand     January 4, 2018
# 3          Daniel Kasman           0              MUBI   November 16, 2017
# 4                    NaN           0      Cinema Scope    October 12, 2017
# ...                  ...         ...               ...                 ...
# 54427      Laura Sinagra           1     Village Voice  September 24, 2002
# 54428  Michael Szymanski           0        Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0   EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0    Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0      Showbizz.net   November 12, 2002
#
# [54432 rows x 8 columns]

# %%
mr.info()

# %%
mr.describe()

# %% [markdown]
# # TMDB Movies

# %%
#chart 5

TM = pd.read_csv("zippedData/tmdb.movies.csv")
TM 

#popularity of the movies will determine which route to take with making movies
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
TM.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
TM.describe()

# %% [markdown]
# # Movie Budgets

# %%
#chart 6

MB = pd.read_csv("zippedData/tn.movie_budgets.csv")
MB

# worldwide_gross - production_budget = total_profit...include those types of genres 
# and directors while considering which types of movies to make
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
MB.info()

# %%
MB.describe()

# %% [markdown]
# # Merging (joining) chart 1 and 6

# %%
joined_df_1_6 = pd.merge(BOM, MB, 
                        left_on = 'title',
                        right_on = 'movie')

joined_df_1_6

#specifically looking at 3 financial cols at the end VS studio col
# Out:
#                            title studio  domestic_gross_x foreign_gross  year  \
# 0                    Toy Story 3     BV       415000000.0     652000000  2010
# 1                      Inception     WB       292600000.0     535700000  2010
# 2            Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                     Iron Man 2   Par.       312400000.0     311500000  2010
# ...                          ...    ...               ...           ...   ...
# 1242                       Gotti     VE         4300000.0           NaN  2018
# 1243                 Ben is Back  RAtt.         3700000.0           NaN  2018
# 1244  Bilal: A New Breed of Hero     VE          491000.0       1700000  2018
# 1245                       Mandy    RLJ         1200000.0           NaN  2018
# 1246                Lean on Pete    A24         1200000.0           NaN  2018
#
#        id  release_date                       movie production_budget  \
# 0      47  Jun 18, 2010                 Toy Story 3      $200,000,000
# 1      38  Jul 16, 2010                   Inception      $160,000,000
# 2      27  May 21, 2010         Shrek Forever After      $165,000,000
# 3      53  Jun 30, 2010  The Twilight Saga: Eclipse       $68,000,000
# 4      15   May 7, 2010                  Iron Man 2      $170,000,000
# ...   ...           ...                         ...               ...
# 1242   64  Jun 15, 2018                       Gotti       $10,000,000
# 1243   95   Dec 7, 2018                 Ben is Back       $13,000,000
# 1244  100   Feb 2, 2018  Bilal: A New Breed of Hero       $30,000,000
# 1245   71  Sep 14, 2018                       Mandy        $6,000,000
# 1246   13   Apr 6, 2018                Lean on Pete        $8,000,000
#
#      domestic_gross_y worldwide_gross
# 0        $415,004,880  $1,068,879,522
# 1        $292,576,195    $835,524,642
# 2        $238,736,787    $756,244,673
# 3        $300,531,751    $706,102,828
# 4        $312,433,331    $621,156,389
# ...               ...             ...
# 1242       $4,286,367      $6,089,100
# 1243       $3,703,182      $9,633,111
# 1244         $490,973        $648,599
# 1245       $1,214,525      $1,427,656
# 1246       $1,163,056      $2,455,027
#
# [1247 rows x 11 columns]

# %% [markdown]
# # Find missing columns for studios

# %%
joined_df_1_6.isna().sum()
# Out:
# title                  0
# studio                 1
# domestic_gross_x       2
# foreign_gross        161
# year                   0
# id                     0
# release_date           0
# movie                  0
# production_budget      0
# domestic_gross_y       0
# worldwide_gross        0
# dtype: int64

# %% [markdown]
# # Data Cleaning joined chart 1 and 6

# %%
#specifically looking at 3 financial cols at the end VS studio col

#take out $ and commas with replace function so we can only have int's

joined_df_1_6['production_budget'] = joined_df_1_6['production_budget'].apply(lambda x: x.replace('$',''))
joined_df_1_6['worldwide_gross'] = joined_df_1_6['worldwide_gross'].apply(lambda x: x.replace(',',''))

joined_df_1_6['domestic_gross_y'] = joined_df_1_6['domestic_gross_y'].apply(lambda x: x.replace('$',''))
joined_df_1_6['domestic_gross_y'] = joined_df_1_6['domestic_gross_y'].apply(lambda x: x.replace(',',''))

joined_df_1_6['worldwide_gross'] = joined_df_1_6['worldwide_gross'].apply(lambda x: x.replace('$',''))
joined_df_1_6['production_budget'] = joined_df_1_6['production_budget'].apply(lambda x: x.replace(',',''))

joined_df_1_6

#Arsh's way threw a pink error:

#joined_df_1_6['production_budget'] = joined_df_1_6['production_budget'].str.replace(',', '')
#joined_df_1_6['worldwide_gross'] = joined_df_1_6['worldwide_gross'].str.replace('$', '')
# Out:
#                            title studio  domestic_gross_x foreign_gross  year  \
# 0                    Toy Story 3     BV       415000000.0     652000000  2010
# 1                      Inception     WB       292600000.0     535700000  2010
# 2            Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                     Iron Man 2   Par.       312400000.0     311500000  2010
# ...                          ...    ...               ...           ...   ...
# 1242                       Gotti     VE         4300000.0           NaN  2018
# 1243                 Ben is Back  RAtt.         3700000.0           NaN  2018
# 1244  Bilal: A New Breed of Hero     VE          491000.0       1700000  2018
# 1245                       Mandy    RLJ         1200000.0           NaN  2018
# 1246                Lean on Pete    A24         1200000.0           NaN  2018
#
#        id  release_date                       movie production_budget  \
# 0      47  Jun 18, 2010                 Toy Story 3         200000000
# 1      38  Jul 16, 2010                   Inception         160000000
# 2      27  May 21, 2010         Shrek Forever After         165000000
# 3      53  Jun 30, 2010  The Twilight Saga: Eclipse          68000000
# 4      15   May 7, 2010                  Iron Man 2         170000000
# ...   ...           ...                         ...               ...
# 1242   64  Jun 15, 2018                       Gotti          10000000
# 1243   95   Dec 7, 2018                 Ben is Back          13000000
# 1244  100   Feb 2, 2018  Bilal: A New Breed of Hero          30000000
# 1245   71  Sep 14, 2018                       Mandy           6000000
# 1246   13   Apr 6, 2018                Lean on Pete           8000000
#
#      domestic_gross_y worldwide_gross
# 0           415004880      1068879522
# 1           292576195       835524642
# 2           238736787       756244673
# 3           300531751       706102828
# 4           312433331       621156389
# ...               ...             ...
# 1242          4286367         6089100
# 1243          3703182         9633111
# 1244           490973          648599
# 1245          1214525         1427656
# 1246          1163056         2455027
#
# [1247 rows x 11 columns]

# %%
joined_df_1_6['domestic_profit']= joined_df_1_6['domestic_gross_y'] - joined_df_1_6['production_budget']

joined_df_1_6['worldwide_profit'] = joined_df_1_6['worldwide_gross'] - joined_df_1_6['production_budget']

joined_df_1_6

#did the math and added 2 profit columns to the end
# Out:
#                            title studio  domestic_gross_x foreign_gross  year  \
# 0                    Toy Story 3     BV       415000000.0     652000000  2010
# 1                      Inception     WB       292600000.0     535700000  2010
# 2            Shrek Forever After   P/DW       238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse   Sum.       300500000.0     398000000  2010
# 4                     Iron Man 2   Par.       312400000.0     311500000  2010
# ...                          ...    ...               ...           ...   ...
# 1242                       Gotti     VE         4300000.0           NaN  2018
# 1243                 Ben is Back  RAtt.         3700000.0           NaN  2018
# 1244  Bilal: A New Breed of Hero     VE          491000.0       1700000  2018
# 1245                       Mandy    RLJ         1200000.0           NaN  2018
# 1246                Lean on Pete    A24         1200000.0           NaN  2018
#
#        id  release_date                       movie  production_budget  \
# 0      47  Jun 18, 2010                 Toy Story 3          200000000
# 1      38  Jul 16, 2010                   Inception          160000000
# 2      27  May 21, 2010         Shrek Forever After          165000000
# 3      53  Jun 30, 2010  The Twilight Saga: Eclipse           68000000
# 4      15   May 7, 2010                  Iron Man 2          170000000
# ...   ...           ...                         ...                ...
# 1242   64  Jun 15, 2018                       Gotti           10000000
# 1243   95   Dec 7, 2018                 Ben is Back           13000000
# 1244  100   Feb 2, 2018  Bilal: A New Breed of Hero           30000000
# 1245   71  Sep 14, 2018                       Mandy            6000000
# 1246   13   Apr 6, 2018                Lean on Pete            8000000
#
#       domestic_gross_y  worldwide_gross  domestic_profit  worldwide_profit
# 0            415004880       1068879522        215004880         868879522
# 1            292576195        835524642        132576195         675524642
# 2            238736787        756244673         73736787         591244673
# 3            300531751        706102828        232531751         638102828
# 4            312433331        621156389        142433331         451156389
# ...                ...              ...              ...               ...
# 1242           4286367          6089100         -5713633          -3910900
# 1243           3703182          9633111         -9296818          -3366889
# 1244            490973           648599        -29509027         -29351401
# 1245           1214525          1427656         -4785475          -4572344
# 1246           1163056          2455027         -6836944          -5544973
#
# [1247 rows x 13 columns]

# %%
#convert strings to int's (can't work with str's to do numerical analysis)

joined_df_1_6['production_budget'] = joined_df_1_6.production_budget.apply(lambda x: int(x))

joined_df_1_6['worldwide_gross'] = joined_df_1_6.worldwide_gross.apply(lambda x: int(x))

# %%
#then do the equation...estimated net gross (profit??) worldwide = worldwide gross - production budget 

# AND estimated net gross (profit??) domestic = domestic gross - production budget

net_worldwide = joined_df_1_6['worldwide_gross'] - joined_df_1_6['production_budget']

# %%
net_worldwide

#***make chart in matplotlib for worldwide
# Out:
# 0       868879522
# 1       675524642
# 2       591244673
# 3       638102828
# 4       451156389
#           ...
# 1242     -3910900
# 1243     -3366889
# 1244    -29351401
# 1245     -4572344
# 1246     -5544973
# Length: 1247, dtype: int64

# %%
joined_df_1_6['domestic_gross_y'] = joined_df_1_6.domestic_gross_y.apply(lambda x: int(x))

#^ converted str to int via lambda functions so we can do math with it

net_domestic = joined_df_1_6['domestic_gross_y'] - joined_df_1_6['production_budget'] 

net_domestic

#^found net estimated profit for domestic sales 

#***make chart in matplotlib for domestic
# Out:
# 0       215004880
# 1       132576195
# 2        73736787
# 3       232531751
# 4       142433331
#           ...
# 1242     -5713633
# 1243     -9296818
# 1244    -29509027
# 1245     -4785475
# 1246     -6836944
# Length: 1247, dtype: int64

# %%
joined_df_1_6.studio.value_counts()   #shows how many times a thing is in the df
# Out:
# Uni.           117
# Fox            110
# WB             102
# Sony            74
# Par.            74
#               ...
# BBC              1
# NM               1
# KE               1
# Strand           1
# Global Road      1
# Name: studio, Length: 99, dtype: int64

# %%
joined_df_1_6.groupby('studio').mean().sort_values(by = 'domestic_profit')

#avg of the money each studio made
# Out:
#          domestic_gross_x         year         id  production_budget  \
# studio
# NM           6.190000e+05  2010.000000  49.000000       7.000000e+07
# Free         1.052667e+05  2011.333333  53.666667       3.416667e+07
# BSC          6.700000e+06  2015.000000  21.000000       4.000000e+07
# EOne         4.484333e+05  2014.333333  44.000000       2.786667e+07
# ALP          2.800000e+03  2011.000000  52.000000       2.600000e+07
# ...                   ...          ...        ...                ...
# WB (NL)      9.237027e+07  2014.162162  48.513514       5.807027e+07
# P/DW         1.682900e+08  2010.900000  43.900000       1.334000e+08
# Uni.         9.205759e+07  2013.914530  52.965812       5.639060e+07
# MGM          8.300000e+07  2014.000000  53.000000       4.300000e+07
# BV           1.795403e+08  2013.902778  40.125000       1.312611e+08
#
#          domestic_gross_y  worldwide_gross  domestic_profit  worldwide_profit
# studio
# NM           6.194230e+05     3.899229e+07    -6.938058e+07     -3.100771e+07
# Free         1.055237e+05     8.597328e+06    -3.406114e+07     -2.556934e+07
# BSC          6.738000e+06     2.673666e+07    -3.326200e+07     -1.326334e+07
# EOne         4.510527e+05     3.696579e+07    -2.741561e+07      9.099122e+06
# ALP          4.247200e+04     2.923959e+06    -2.595753e+07     -2.307604e+07
# ...                   ...              ...              ...               ...
# WB (NL)      9.236838e+07     2.308342e+08     3.429811e+07      1.727639e+08
# P/DW         1.682915e+08     5.078028e+08     3.489147e+07      3.744028e+08
# Uni.         9.151146e+07     2.335837e+08     3.512086e+07      1.771931e+08
# MGM          8.299287e+07     1.397796e+08     3.999287e+07      9.677964e+07
# BV           1.795298e+08     4.623058e+08     4.826864e+07      3.310447e+08
#
# [99 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig ,ax = plt.subplots(figsize= (30,30))
ax.set_title('danielles plot')
sns.barplot(x = 'studio' ,y = 'domestic_profit',data = joined_df_1_6)
plt.show()

#how to make x axis values 45 degrees

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig ,ax = plt.subplots(figsize= (30,30))
ax.set_title('danielles plot')
sns.barplot(x = 'studio' ,y = 'domestic_profit',data = joined_df_1_6.groupby('studio').mean().sort_values(by = 'domestic_profit').reset_index().head(20))
plt.show()

#how to make x axis values 45 degrees

# %% [markdown]
# # Merging (joining) chart 1 and 5

# %%
joined_df_1_5 = pd.merge(BOM, TM)

joined_df_1_5

#specifically looking at studio col VS popularity col
# Out:
#                            title  studio  domestic_gross foreign_gross  year  \
# 0                    Toy Story 3      BV     415000000.0     652000000  2010
# 1                      Inception      WB     292600000.0     535700000  2010
# 2            Shrek Forever After    P/DW     238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse    Sum.     300500000.0     398000000  2010
# 4                     Iron Man 2    Par.     312400000.0     311500000  2010
# ...                          ...     ...             ...           ...   ...
# 2698                  The Escape     IFC         14000.0           NaN  2018
# 2699                  The Escape     IFC         14000.0           NaN  2018
# 2700                    Souvenir  Strand         11400.0           NaN  2018
# 2701                   The Quake   Magn.          6200.0           NaN  2018
# 2702           An Actor Prepares   Grav.          1700.0           NaN  2018
#
#       Unnamed: 0                genre_ids      id original_language  \
# 0              7          [16, 10751, 35]   10193                en
# 1              4            [28, 878, 12]   27205                en
# 2             38  [35, 12, 14, 16, 10751]   10192                en
# 3             15      [12, 14, 18, 10749]   24021                en
# 4              2            [12, 28, 878]   10138                en
# ...          ...                      ...     ...               ...
# 2698       16803                 [53, 28]  459814                en
# 2699       19053                 [53, 28]  417004                en
# 2700       18483                 [35, 18]  408258                fr
# 2701       24107                     [12]  416194                no
# 2702       24419                 [35, 18]  434596                en
#
#                   original_title  popularity release_date  vote_average  \
# 0                    Toy Story 3      24.445   2010-06-17           7.7
# 1                      Inception      27.920   2010-07-16           8.3
# 2            Shrek Forever After      15.041   2010-05-16           6.1
# 3     The Twilight Saga: Eclipse      20.340   2010-06-23           6.0
# 4                     Iron Man 2      28.515   2010-05-07           6.8
# ...                          ...         ...          ...           ...
# 2698                  The Escape       0.600   2015-08-14           7.0
# 2699                  The Escape       1.176   2016-10-23           6.6
# 2700                    Souvenir       2.130   2016-09-08           5.8
# 2701                    Skjelvet      11.051   2018-12-14           6.7
# 2702           An Actor Prepares       7.244   2018-08-31           6.5
#
#       vote_count
# 0           8340
# 1          22186
# 2           3843
# 3           4909
# 4          12368
# ...          ...
# 2698           1
# 2699          10
# 2700          14
# 2701          81
# 2702          10
#
# [2703 rows x 14 columns]

# %% [markdown]
# # Data Cleaning joined chart 1 and 5

# %%
joined_df_1_5['popularity'] = joined_df_1_5.popularity.apply(lambda x: int(x))

joined_df_1_5
# Out:
#                            title  studio  domestic_gross foreign_gross  year  \
# 0                    Toy Story 3      BV     415000000.0     652000000  2010
# 1                      Inception      WB     292600000.0     535700000  2010
# 2            Shrek Forever After    P/DW     238700000.0     513900000  2010
# 3     The Twilight Saga: Eclipse    Sum.     300500000.0     398000000  2010
# 4                     Iron Man 2    Par.     312400000.0     311500000  2010
# ...                          ...     ...             ...           ...   ...
# 2698                  The Escape     IFC         14000.0           NaN  2018
# 2699                  The Escape     IFC         14000.0           NaN  2018
# 2700                    Souvenir  Strand         11400.0           NaN  2018
# 2701                   The Quake   Magn.          6200.0           NaN  2018
# 2702           An Actor Prepares   Grav.          1700.0           NaN  2018
#
#       Unnamed: 0                genre_ids      id original_language  \
# 0              7          [16, 10751, 35]   10193                en
# 1              4            [28, 878, 12]   27205                en
# 2             38  [35, 12, 14, 16, 10751]   10192                en
# 3             15      [12, 14, 18, 10749]   24021                en
# 4              2            [12, 28, 878]   10138                en
# ...          ...                      ...     ...               ...
# 2698       16803                 [53, 28]  459814                en
# 2699       19053                 [53, 28]  417004                en
# 2700       18483                 [35, 18]  408258                fr
# 2701       24107                     [12]  416194                no
# 2702       24419                 [35, 18]  434596                en
#
#                   original_title  popularity release_date  vote_average  \
# 0                    Toy Story 3          24   2010-06-17           7.7
# 1                      Inception          27   2010-07-16           8.3
# 2            Shrek Forever After          15   2010-05-16           6.1
# 3     The Twilight Saga: Eclipse          20   2010-06-23           6.0
# 4                     Iron Man 2          28   2010-05-07           6.8
# ...                          ...         ...          ...           ...
# 2698                  The Escape           0   2015-08-14           7.0
# 2699                  The Escape           1   2016-10-23           6.6
# 2700                    Souvenir           2   2016-09-08           5.8
# 2701                    Skjelvet          11   2018-12-14           6.7
# 2702           An Actor Prepares           7   2018-08-31           6.5
#
#       vote_count
# 0           8340
# 1          22186
# 2           3843
# 3           4909
# 4          12368
# ...          ...
# 2698           1
# 2699          10
# 2700          14
# 2701          81
# 2702          10
#
# [2703 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig ,ax = plt.subplots(figsize= (30,30))
ax.set_title('danielles plot')
sns.barplot(x = 'studio' ,y = 'popularity',data = joined_df_1_5)
plt.show()

#how to make x axis values 45 degrees

# %%
joined_df_1_5.studio.value_counts()   #shows how many times a thing is in the df
# Out:
# Uni.     153
# IFC      142
# Fox      138
# WB       120
# Magn.    114
#         ...
# SEG        1
# TA         1
# Crnth      1
# Rog.       1
# UTMW       1
# Name: studio, Length: 196, dtype: int64

# %%
joined_df_1_5.groupby('studio').mean().sort_values(by = 'popularity')

#avg of the money each studio made
# Out:
#         domestic_gross         year    Unnamed: 0             id  popularity  \
# studio
# FEF       6.130000e+05  2013.000000   9786.000000  217576.000000    0.000000
# KKM       5.550000e+05  2011.000000   4839.000000   97659.000000    0.000000
# ITL       4.110000e+04  2015.000000  16184.500000  336472.000000    0.000000
# UTMW      6.250000e+04  2017.000000  13009.000000  420172.000000    0.000000
# Argo.     2.930000e+04  2011.000000   4255.000000   60063.000000    0.000000
# ...                ...          ...           ...            ...         ...
# LG/S      4.444359e+07  2014.358974  12552.564103  220202.589744   14.717949
# Fox       8.297246e+07  2014.072464  11787.847826  193087.094203   14.775362
# WB        9.053167e+07  2013.900000  11941.616667  197029.858333   14.958333
# MGM       8.300000e+07  2014.000000  11990.000000  251789.000000   18.000000
# BV        2.008534e+08  2014.105769  11679.673077  166624.173077   19.192308
#
#         vote_average   vote_count
# studio
# FEF         4.800000     3.000000
# KKM         5.600000     7.000000
# ITL         4.100000     7.000000
# UTMW        6.000000     2.000000
# Argo.       7.000000     2.000000
# ...              ...          ...
# LG/S        6.253846  2741.153846
# Fox         6.339130  3142.173913
# WB          6.504167  3155.600000
# MGM         6.350000  1809.500000
# BV          6.852885  4852.903846
#
# [196 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig ,ax = plt.subplots(figsize= (30,30))
ax.set_title('danielles plot')
sns.barplot(x = 'studio' ,y = 'popularity',data = joined_df_1_5.groupby('studio').mean().sort_values(by = 'popularity').reset_index().head(20))
plt.show()

#how to make x axis values 45 degrees
